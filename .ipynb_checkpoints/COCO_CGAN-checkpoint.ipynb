# %% [markdown]
# <a href="https://colab.research.google.com/github/victorgsosa/GANMarketing/blob/main/COCO_CGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import tensorflow_datasets as tfds

# %%
(train_dataset, val_dataset), dataset_info = tfds.load(
    "coco/2017", split=["train", "validation"], with_info=True, data_dir="data"
)
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to data\coco\2017\1.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow_datasets\core\download\extractor.py in _sync_extract(self, from_path, method, to_path)
#      89         dst_path = path and os.path.join(to_path_tmp, path) or to_path_tmp
# ---> 90         _copy(handle, dst_path)
#      91     except BaseException as err:
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow_datasets\core\download\extractor.py in _copy(src_file, dest_path)
#     125         break
# --> 126       dest_file.write(data)
#     127
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow\python\lib\io\file_io.py in write(self, file_content)
#     101     """Writes file_content to the file. Appends to the end of the file."""
# --> 102     self._prewrite_check()
#     103     self._writable_file.append(compat.as_bytes(file_content))
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow\python\lib\io\file_io.py in _prewrite_check(self)
#      86                                            "File isn't open for writing")
# ---> 87       self._writable_file = _pywrap_file_io.WritableFile(
#      88           compat.path_to_bytes(self.__name), compat.as_bytes(self.__mode))
#
# NotFoundError: Failed to create a NewWriteableFile: data\downloads\extracted\ZIP.images.cocoda.org_annota_image_info_test205S9BLdcZWsj5jXgrRMbdMOoQJB6fQlIfZ2EPvgVadPg.zip.incomplete_1491384d0af94541850728c1051a3c5b\annotations\image_info_test-dev2017.json : El sistema no puede encontrar la ruta especificada.
# ; No such process
#
# During handling of the above exception, another exception occurred:
#
# ExtractError                              Traceback (most recent call last)
# <ipython-input-4-ba718be0f1e5> in <module>
# ----> 1 (train_dataset, val_dataset), dataset_info = tfds.load(
#       2     "coco/2017", split=["train", "validation"], with_info=True, data_dir="data"
#       3 )
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow_datasets\core\load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     331   if download:
#     332     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 333     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     334
#     335   if as_dataset_kwargs is None:
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow_datasets\core\dataset_builder.py in download_and_prepare(self, download_dir, download_config)
#     437           # Old version of TF are not os.PathLike compatible
#     438           with tf_compat.mock_gfile_pathlike():
# --> 439             self._download_and_prepare(
#     440                 dl_manager=dl_manager,
#     441                 download_config=download_config,
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow_datasets\core\dataset_builder.py in _download_and_prepare(self, dl_manager, download_config)
#    1131       else:
#    1132         optional_pipeline_kwargs = {}
# -> 1133       split_generators = self._split_generators(  # pylint: disable=unexpected-keyword-arg
#    1134           dl_manager, **optional_pipeline_kwargs)
#    1135       # TODO(tfds): Could be removed once all datasets are migrated.
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow_datasets\object_detection\coco.py in _split_generators(self, dl_manager)
#     241     # once.
#     242     root_url = 'http://images.cocodataset.org/'
# --> 243     extracted_paths = dl_manager.download_and_extract({
#     244         key: root_url + url for key, url in urls.items()
#     245     })
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow_datasets\core\download\download_manager.py in download_and_extract(self, url_or_urls)
#     635     with self._downloader.tqdm():
#     636       with self._extractor.tqdm():
# --> 637         return _map_promise(self._download_extract, url_or_urls)
#     638
#     639   @property
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow_datasets\core\download\download_manager.py in _map_promise(map_fn, all_inputs)
#     776   """Map the function into each element and resolve the promise."""
#     777   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 778   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     779   return res
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow_datasets\core\download\download_manager.py in <lambda>(p)
#     776   """Map the function into each element and resolve the promise."""
#     777   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 778   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     779   return res
#
# C:\anaconda3\envs\ai_env\lib\site-packages\promise\promise.py in get(self, timeout)
#     510         target = self._target()
#     511         self._wait(timeout or DEFAULT_TIMEOUT)
# --> 512         return self._target_settled_value(_raise=True)
#     513
#     514     def _target_settled_value(self, _raise=False):
#
# C:\anaconda3\envs\ai_env\lib\site-packages\promise\promise.py in _target_settled_value(self, _raise)
#     514     def _target_settled_value(self, _raise=False):
#     515         # type: (bool) -> Any
# --> 516         return self._target()._settled_value(_raise)
#     517
#     518     _value = _reason = _target_settled_value
#
# C:\anaconda3\envs\ai_env\lib\site-packages\promise\promise.py in _settled_value(self, _raise)
#     224             if _raise:
#     225                 raise_val = self._fulfillment_handler0
# --> 226                 reraise(type(raise_val), raise_val, self._traceback)
#     227             return self._fulfillment_handler0
#     228
#
# C:\anaconda3\envs\ai_env\lib\site-packages\six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# C:\anaconda3\envs\ai_env\lib\site-packages\promise\promise.py in handle_future_result(future)
#     842         # type: (Any) -> None
#     843         try:
# --> 844             resolve(future.result())
#     845         except Exception as e:
#     846             tb = exc_info()[2]
#
# C:\anaconda3\envs\ai_env\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# C:\anaconda3\envs\ai_env\lib\concurrent\futures\_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# C:\anaconda3\envs\ai_env\lib\concurrent\futures\thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# C:\anaconda3\envs\ai_env\lib\site-packages\tensorflow_datasets\core\download\extractor.py in _sync_extract(self, from_path, method, to_path)
#     100             'https://docs.python.org/3/using/windows.html#removing-the-max-path-limitation'
#     101         )
# --> 102       raise ExtractError(msg)
#     103     # `tf.io.gfile.Rename(overwrite=True)` doesn't work for non empty
#     104     # directories, so delete destination first, if it already exists.
#
# ExtractError: Error while extracting data\downloads\images.cocoda.org_annota_image_info_test205S9BLdcZWsj5jXgrRMbdMOoQJB6fQlIfZ2EPvgVadPg.zip to data\downloads\extracted\ZIP.images.cocoda.org_annota_image_info_test205S9BLdcZWsj5jXgrRMbdMOoQJB6fQlIfZ2EPvgVadPg.zip (file: annotations\image_info_test-dev2017.json) : Failed to create a NewWriteableFile: data\downloads\extracted\ZIP.images.cocoda.org_annota_image_info_test205S9BLdcZWsj5jXgrRMbdMOoQJB6fQlIfZ2EPvgVadPg.zip.incomplete_1491384d0af94541850728c1051a3c5b\annotations\image_info_test-dev2017.json : El sistema no puede encontrar la ruta especificada.
# ; No such process

# %%
def preprocess_data(sample):
    """Applies preprocessing step to a single sample

    Arguments:
      sample: A dict representing a single training sample.

    Returns:
      image: Resized and padded image with random horizontal flipping applied.
      bbox: Bounding boxes with the shape `(num_objects, 4)` where each box is
        of the format `[x, y, width, height]`.
      class_id: An tensor representing the class id of the objects, having
        shape `(num_objects,)`.
    """
    image = sample["image"]
    bbox = swap_xy(sample["objects"]["bbox"])
    class_id = tf.cast(sample["objects"]["label"], dtype=tf.int32)

    image, bbox = random_flip_horizontal(image, bbox)
    image, image_shape, _ = resize_and_pad_image(image)

    return image, class_id

# %%
autotune = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.map(preprocess_data, num_parallel_calls=autotune)
train_dataset[0]
